# %% [markdown]
# <a href="https://colab.research.google.com/github/Amri1003/Deep_Learning_Projects/blob/main/YOLO_WithDisplay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required library
# !pip install ultralytics opencv-python matplotlib

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
print('imported')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# imported

# %%
# load the yolo model
model=YOLO('yolov8n.pt') #n-nano

# %%
print(model)

# %%
image_path='/content/detect(1).jpg'

# %%
# run the object detection
result=model(image_path)
# Out:
# image 1/1 /content/detect(1).jpg: 384x640 7 persons, 1 bicycle, 1 car, 2 buss, 1 truck, 2 traffic lights, 332.5ms
# Speed: 13.3ms preprocess, 332.5ms inference, 40.9ms postprocess per image at shape (1, 3, 384, 640)

# %%
# display results
for r in result:
  im_array=r.plot()
  # convert BGR to RGB
  im_rgb=cv2.cvtColor(im_array,cv2.COLOR_BGR2RGB)
  plt.figure(figsize=(10,6))
  plt.imshow(im_rgb)
  plt.axis('off')
  plt.show()

# %%
image_path='/content/cycling001-1024x683.jpg'

# %%
# run the object detection
result=model(image_path)
# Out:
# image 1/1 /content/cycling001-1024x683.jpg: 448x640 1 person, 3 bicycles, 1 car, 312.4ms
# Speed: 8.7ms preprocess, 312.4ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)

# %%
# display results
for r in result:
  im_array=r.plot()
  # convert BGR to RGB
  im_rgb=cv2.cvtColor(im_array,cv2.COLOR_BGR2RGB)
  plt.figure(figsize=(10,6))
  plt.imshow(im_rgb)
  plt.axis('off')
  plt.show()

# %%
model.names
